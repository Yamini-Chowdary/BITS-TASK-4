# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sb 
# Size the plot appropriately for online display
plt.rcParams['figure.figsize'] = (12.0, 10.0)

# %%
types = {'StateHoliday': np.dtype(str)}
train = pd.read_csv("./assets/train_v2.csv", parse_dates=[2], nrows=66901, dtype=types)
store = pd.read_csv("./assets/store.csv")

# %%
not_open = train[(train['Open'] == 0) & (train['Sales'] != 0)]
print("No closed store with sales: " + str(not_open.size == 0))
# Out:
# No closed store with sales: True

# %%
no_sales = train[(train['Open'] == 1) & (train['Sales'] <= 0)]
print("No open store with no sales: " + str(no_sales.size == 0))
# Out:
# No open store with no sales: True

# %%
train = train.loc[train['Sales'] > 0]
assert(train[train['Sales'] == 0].size == 0)

# %%
dates = pd.to_datetime(train['Date'], format="%Y%m%d:%H:%M:%S.%f").sort_values()
dates = dates.unique()
start_date = dates[0]
end_date = dates[-1]
print("Start date: ", start_date)
print("End Date: ", end_date)
date_range = pd.date_range(start_date, end_date).values
assert(all(dates == date_range))
# Out:
# Start date:  2014-11-26 00:00:00
# End Date:  2015-01-30 00:00:00

# %%
f, ax = plt.subplots(7, sharex=True, sharey=True)
for i in range(1, 8):
    mask = train[train['DayOfWeek'] == i]
    ax[i - 1].set_title("Day {0}".format(i))
    ax[i - 1].scatter(mask['Customers'], mask['Sales'], label=i)

plt.legend()
plt.xlabel('Customers')
plt.ylabel('Sales')
plt.show()

# %%
import matplotlib.pyplot as plt

# Scatter plot
scatter = plt.scatter(train['Customers'], train['Sales'], c=train['DayOfWeek'], alpha=0.7, cmap='viridis')

# Adding colorbar
plt.colorbar(scatter, label='DayOfWeek')

# Labels
plt.xlabel('Customers')
plt.ylabel('Sales')

# Display plot
plt.show()

# %%
for i in ["0", "a", "b", "c"]:
    data = train[train['StateHoliday'] == i]
    if (len(data) == 0):
        continue
    plt.scatter(data['Customers'], data['Sales'], label=i)

plt.legend()
plt.xlabel('Customers')
plt.ylabel('Sales')
plt.show()

# %%
for i in [0, 1]:
    data = train[train['SchoolHoliday'] == i]
    if (len(data) == 0):
        continue
    plt.scatter(data['Customers'], data['Sales'], label=i)

plt.legend()
plt.xlabel('Customers')
plt.ylabel('Sales')
plt.show()

# %%
for i in [0, 1]:
    data = train[train['Promo'] == i]
    if (len(data) == 0):
        continue
    plt.scatter(data['Customers'], data['Sales'], label=i)

plt.legend()
plt.xlabel('Customers')
plt.ylabel('Sales')
plt.show()

# %%
train['SalesPerCustomer'] = train['Sales'] / train['Customers']

avg_store = train.groupby('Store')[['Sales', 'Customers', 'SalesPerCustomer']].mean()
avg_store.rename(columns=lambda x: 'Avg' + x, inplace=True)
store = pd.merge(avg_store.reset_index(), store, on='Store')
store.head()
# Out:
#    Store      AvgSales  AvgCustomers  AvgSalesPerCustomer StoreType  \
# 0      1   5574.037037    644.407407             8.574182         c
# 1      2   5593.407407    602.833333             9.132443         a
# 2      3   7560.740741    797.296296             9.363221         a
# 3      4  10730.296296   1424.888889             7.481731         c
# 4      5   5313.981481    564.833333             9.273212         a
#
#   Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0          a               1270.0                        9.0
# 1          a                570.0                       11.0
# 2          a              14130.0                       12.0
# 3          c                620.0                        9.0
# 4          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# 2  Jan,Apr,Jul,Oct
# 3              NaN
# 4              NaN

# %%
for i in ['a', 'b', 'c', 'd']:
    data = store[store['StoreType'] == i]
    if (len(data) == 0):
        continue
    plt.scatter(data['AvgCustomers'], data['AvgSales'], label=i)

plt.legend()
plt.xlabel('Average Customers')
plt.ylabel('Average Sales')
plt.show()

# %%
for i in [0, 1]:
    data = store[store['Promo2'] == i]
    if (len(data) == 0):
        continue
    plt.scatter(data['AvgCustomers'], data['AvgSales'], label=i)

plt.legend()
plt.xlabel('Average Customers')
plt.ylabel('Average Sales')
plt.show()

# %%
# fill NaN values
store["CompetitionDistance"].fillna(-1)
plt.scatter(store['CompetitionDistance'], store['AvgSales'])

plt.xlabel('CompetitionDistance')
plt.ylabel('Average Sales')
plt.show()

# %%
def build_features(train, store):
    # Convert string types into integers
    store['StoreType'] = store['StoreType'].astype('category').cat.codes
    store['Assortment'] = store['Assortment'].astype('category').cat.codes
    train["StateHoliday"] = train["StateHoliday"].astype('category').cat.codes

    merged = pd.merge(train, store, on='Store', how='left')
    
    # remove NaNs
    NaN_replace = 0
    merged.fillna(NaN_replace, inplace=True)
    
    merged['Year'] = merged.Date.dt.year
    merged['Month'] = merged.Date.dt.month
    merged['Day'] = merged.Date.dt.day
    merged['Week'] = merged.Date.dt.week
    
    # Number of months that competition has existed for
    merged['MonthsCompetitionOpen'] = \
        12 * (merged['Year'] - merged['CompetitionOpenSinceYear']) + \
        (merged['Month'] - merged['CompetitionOpenSinceMonth'])
    merged.loc[merged['CompetitionOpenSinceYear'] ==
               NaN_replace, 'MonthsCompetitionOpen'] = NaN_replace
    
    # Number of weeks that promotion has existed for
    merged['WeeksPromoOpen'] = \
        12 * (merged['Year'] - merged['Promo2SinceYear']) + \
        (merged['Date'].dt.weekofyear - merged['Promo2SinceWeek'])
    merged.loc[merged['Promo2SinceYear'] == 
               NaN_replace, 'WeeksPromoOpen'] = NaN_replace

    toInt = [
        'CompetitionOpenSinceMonth',
        'CompetitionOpenSinceYear',
        'Promo2SinceWeek', 
        'Promo2SinceYear', 
        'MonthsCompetitionOpen', 
        'WeeksPromoOpen'
    ]
    merged[toInt] = merged[toInt].astype(int)

    return merged

med_store = train.groupby('Store')[['Sales', 'Customers', 'SalesPerCustomer']].median()
med_store.rename(columns=lambda x: 'Med' + x, inplace=True)

store = pd.merge(med_store.reset_index(), store, on='Store')
features = build_features(train, store)
features.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo  StateHoliday  \
# 0      1          5 2015-01-30   5577        616     1      1             0
# 1      2          5 2015-01-30   5919        624     1      1             0
# 2      3          5 2015-01-30   6911        678     1      1             0
# 3      4          5 2015-01-30  13307       1632     1      1             0
# 4      5          5 2015-01-30   5640        617     1      1             0
#
#    SchoolHoliday  SalesPerCustomer  ...  Promo2  Promo2SinceWeek  \
# 0              0          9.053571  ...       0                0
# 1              0          9.485577  ...       1               13
# 2              0         10.193215  ...       1               14
# 3              0          8.153799  ...       0                0
# 4              0          9.141005  ...       0                0
#
#    Promo2SinceYear    PromoInterval  Year  Month  Day  Week  \
# 0                0                0  2015      1   30     5
# 1             2010  Jan,Apr,Jul,Oct  2015      1   30     5
# 2             2011  Jan,Apr,Jul,Oct  2015      1   30     5
# 3                0                0  2015      1   30     5
# 4                0                0  2015      1   30     5
#
#    MonthsCompetitionOpen  WeeksPromoOpen
# 0                     76               0
# 1                     86              52
# 2                     97              39
# 3                     64               0
# 4                     -3               0
#
# [5 rows x 31 columns]

# %%
from sklearn.model_selection import train_test_split
X = [
    'Store', 
    'Customers',
    'CompetitionDistance', 

    'Promo', 
    'Promo2', 

#     'SchoolHoliday',
    'StateHoliday',
    'StoreType',
    'Assortment',

    'AvgSales',
    'AvgCustomers',
    'AvgSalesPerCustomer',
    
    'MedSales',
    'MedCustomers',
    'MedSalesPerCustomer',

    'DayOfWeek',
    'Week',
    'Day',
    'Month',
    'Year',

    'CompetitionOpenSinceMonth',
    'CompetitionOpenSinceYear',
    'Promo2SinceWeek',
    'Promo2SinceYear',

#     'MonthsCompetitionOpen',
#     'WeeksPromoOpen'
]
X_train, X_test, y_train, y_test = train_test_split(
    features[X], features['Sales'], test_size=0.15, random_state=10)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer

# Error calculating function according to kaggle
def rmspe(y, y_hat):
    return np.sqrt(np.mean(((y - y_hat) / y) ** 2))

rmpse_scorer = make_scorer(rmspe, greater_is_better = False) # Loss function

def score(model, X_train, y_train, y_test, y_hat):
    score = cross_val_score(model, X_train, y_train, scoring=rmpse_scorer, cv=5)
    print('Mean', score.mean())
    print('Variance', score.var())
    print('RMSPE', rmspe(y_test, y_hat))

def plot_importance(model):
    k = list(zip(X, model.feature_importances_))
    k.sort(key=lambda tup: tup[1])

    labels, vals = zip(*k)
    
    plt.barh(np.arange(len(X)), vals, align='center')
    plt.yticks(np.arange(len(X)), labels)

# %%
from sklearn.tree import DecisionTreeRegressor
decision_tree = DecisionTreeRegressor()
decision_tree.fit(X_train, y_train)
plot_importance(decision_tree)

# %%
y_hat = decision_tree.predict(X_test)
score(decision_tree, X_train, y_train, y_test, y_hat)
# Out:
# Mean -0.08495412673313536
# Variance 1.0085923035949457e-06
# RMSPE 0.08272473644632616

# %%
from sklearn.ensemble import RandomForestRegressor
randomForest = RandomForestRegressor(n_estimators=25, n_jobs=-1, verbose=1)
randomForest.fit(X_train, y_train)
plot_importance(randomForest)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:    8.3s finished

# %%
y_hat = randomForest.predict(X_test)
score(randomForest, X_train, y_train, y_test, y_hat)
# Out:
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  25 out of  25 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:   13.3s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  25 out of  25 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:    6.9s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  25 out of  25 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:    6.2s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  25 out of  25 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:    6.5s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  25 out of  25 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# Mean -0.06080980622779072
# Variance 5.458489031870373e-07
# RMSPE 0.059600547682879826
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:    6.8s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  25 out of  25 | elapsed:    0.0s finished

# %%
import xgboost as xgb

def rmspe_xg(yhat, y):
    y = np.expm1(y.get_label())
    yhat = np.expm1(yhat)
    return "rmspe", rmspe(y,yhat)

xgboost_tree = xgb.XGBRegressor(
    n_jobs = -1,
    n_estimators = 1000,
    eta = 0.1,
    max_depth = 2,
    min_child_weight = 2,
    subsample = 0.8,
    colsample_bytree = 0.8,
    tree_method = 'exact',
    reg_alpha = 0.05,
    silent = 0,
    random_state = 1023
)
xgboost_tree.fit(X_train[X], np.log1p(y_train), 
                 eval_set = [(X_train[X], np.log1p(y_train)), (X_test[X], np.log1p(y_test))],
                 eval_metric = rmspe_xg,
                 early_stopping_rounds = 300
                )
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [21:12:30] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:7.53663	validation_1-rmse:7.53603	validation_0-rmspe:0.999568	validation_1-rmspe:0.99957
# Multiple eval metrics have been passed: 'validation_1-rmspe' will be used for early stopping.
#
# Will train until validation_1-rmspe hasn't improved in 300 rounds.
# [1]	validation_0-rmse:6.78395	validation_1-rmse:6.78346	validation_0-rmspe:0.998921	validation_1-rmspe:0.998924
# [2]	validation_0-rmse:6.10655	validation_1-rmse:6.10602	validation_0-rmspe:0.997745	validation_1-rmspe:0.99775
# [340]	validation_0-rmse:0.057897	validation_1-rmse:0.057903	validation_0-rmspe:0.057906	validation_1-rmspe:0.057761
# [341]	validation_0-rmse:0.05788	validation_1-rmse:0.057887	validation_0-rmspe:0.05789	validation_1-rmspe:0.057746
# [342]	validation_0-rmse:0.057862	validation_1-rmse:0.057873	validation_0-rmspe:0.05787	validation_1-rmspe:0.057732
# [343]	validation_0-rmse:0.05785	validation_1-rmse:0.057859	validation_0-rmspe:0.057863	validation_1-rmspe:0.057723
# [344]	validation_0-rmse:0.057837	validation_1-rmse:0.057852	validation_0-rmspe:0.057849	validation_1-rmspe:0.057716
# [345]	validation_0-rmse:0.057829	validation_1-rmse:0.057843	validation_0-rmspe:0.057841	validation_1-rmspe:0.057706
# [346]	validation_0-rmse:0.057823	validation_1-rmse:0.05784	validation_0-rmspe:0.057834	validation_1-rmspe:0.057705
# [347]	validation_0-rmse:0.057808	validation_1-rmse:0.057831	validation_0-rmspe:0.057816	validation_1-rmspe:0.057693
# [348]	validation_0-rmse:0.057785	validation_1-rmse:0.057802	validation_0-rmspe:0.057793	validation_1-rmspe:0.057663
# [349]	validation_0-rmse:0.057755	validation_1-rmse:0.057769	validation_0-rmspe:0.057763	validation_1-rmspe:0.05763
# [350]	validation_0-rmse:0.057738	validation_1-rmse:0.057755	validation_0-rmspe:0.057743	validation_1-rmspe:0.057612
# [351]	validation_0-rmse:0.057715	validation_1-rmse:0.057733	validation_0-rmspe:0.05772	validation_1-rmspe:0.05759
# [352]	validation_0-rmse:0.057705	validation_1-rmse:0.057726	validation_0-rmspe:0.057708	validation_1-rmspe:0.057582
# [353]	validation_0-rmse:0.057697	validation_1-rmse:0.057719	validation_0-rmspe:0.057698	validation_1-rmspe:0.057573
# [354]	validation_0-rmse:0.057677	validation_1-rmse:0.057698	validation_0-rmspe:0.057678	validation_1-rmspe:0.057552
# [355]	validation_0-rmse:0.057662	validation_1-rmse:0.057684	validation_0-rmspe:0.057664	validation_1-rmspe:0.05754
# [356]	validation_0-rmse:0.057649	validation_1-rmse:0.057673	validation_0-rmspe:0.057649	validation_1-rmspe:0.05753
# [357]	validation_0-rmse:0.05764	validation_1-rmse:0.057663	validation_0-rmspe:0.057643	validation_1-rmspe:0.057522
# [358]	validation_0-rmse:0.057624	validation_1-rmse:0.057636	validation_0-rmspe:0.057628	validation_1-rmspe:0.057496
# [359]	validation_0-rmse:0.057607	validation_1-rmse:0.05763	validation_0-rmspe:0.057608	validation_1-rmspe:0.057488
# [360]	validation_0-rmse:0.057595	validation_1-rmse:0.057619	validation_0-rmspe:0.057595	validation_1-rmspe:0.057476
# [361]	validation_0-rmse:0.057584	validation_1-rmse:0.057603	validation_0-rmspe:0.057587	validation_1-rmspe:0.057463
# [362]	validation_0-rmse:0.057569	validation_1-rmse:0.057582	validation_0-rmspe:0.057571	validation_1-rmspe:0.057441
# [363]	validation_0-rmse:0.057557	validation_1-rmse:0.057574	validation_0-rmspe:0.057562	validation_1-rmspe:0.057437
# [388]	validation_0-rmse:0.057199	validation_1-rmse:0.057234	validation_0-rmspe:0.057199	validation_1-rmspe:0.057099
# [389]	validation_0-rmse:0.057193	validation_1-rmse:0.057231	validation_0-rmspe:0.057193	validation_1-rmspe:0.057097
# [390]	validation_0-rmse:0.057182	validation_1-rmse:0.057221	validation_0-rmspe:0.057181	validation_1-rmspe:0.057087
# [391]	validation_0-rmse:0.057165	validation_1-rmse:0.057205	validation_0-rmspe:0.057165	validation_1-rmspe:0.057071
# [392]	validation_0-rmse:0.057153	validation_1-rmse:0.057196	validation_0-rmspe:0.057152	validation_1-rmspe:0.057061
# [393]	validation_0-rmse:0.057146	validation_1-rmse:0.057189	validation_0-rmspe:0.057147	validation_1-rmspe:0.057057
# [394]	validation_0-rmse:0.057137	validation_1-rmse:0.057178	validation_0-rmspe:0.057139	validation_1-rmspe:0.057046
# [395]	validation_0-rmse:0.057128	validation_1-rmse:0.057172	validation_0-rmspe:0.057127	validation_1-rmspe:0.057039
# [396]	validation_0-rmse:0.057112	validation_1-rmse:0.057153	validation_0-rmspe:0.057111	validation_1-rmspe:0.057019
# [397]	validation_0-rmse:0.057108	validation_1-rmse:0.057151	validation_0-rmspe:0.057105	validation_1-rmspe:0.057015
# [398]	validation_0-rmse:0.057077	validation_1-rmse:0.05712	validation_0-rmspe:0.057076	validation_1-rmspe:0.056986
# [399]	validation_0-rmse:0.057067	validation_1-rmse:0.057112	validation_0-rmspe:0.057068	validation_1-rmspe:0.056982
# [400]	validation_0-rmse:0.057056	validation_1-rmse:0.057098	validation_0-rmspe:0.057058	validation_1-rmspe:0.056968
# [401]	validation_0-rmse:0.057047	validation_1-rmse:0.057086	validation_0-rmspe:0.057049	validation_1-rmspe:0.056955
# [402]	validation_0-rmse:0.057036	validation_1-rmse:0.057075	validation_0-rmspe:0.057037	validation_1-rmspe:0.05694
# [403]	validation_0-rmse:0.057005	validation_1-rmse:0.057039	validation_0-rmspe:0.057008	validation_1-rmspe:0.056905
# [404]	validation_0-rmse:0.057001	validation_1-rmse:0.057039	validation_0-rmspe:0.057004	validation_1-rmspe:0.056907
# [405]	validation_0-rmse:0.05699	validation_1-rmse:0.057031	validation_0-rmspe:0.056993	validation_1-rmspe:0.056899
# [406]	validation_0-rmse:0.056982	validation_1-rmse:0.057028	validation_0-rmspe:0.056989	validation_1-rmspe:0.056897
# [407]	validation_0-rmse:0.056976	validation_1-rmse:0.05702	validation_0-rmspe:0.056981	validation_1-rmspe:0.056889
# [408]	validation_0-rmse:0.056962	validation_1-rmse:0.057009	validation_0-rmspe:0.056967	validation_1-rmspe:0.056877
# [409]	validation_0-rmse:0.056955	validation_1-rmse:0.056997	validation_0-rmspe:0.056959	validation_1-rmspe:0.056866
# [410]	validation_0-rmse:0.056941	validation_1-rmse:0.056992	validation_0-rmspe:0.056943	validation_1-rmspe:0.056861
# [411]	validation_0-rmse:0.056935	validation_1-rmse:0.056989	validation_0-rmspe:0.056936	validation_1-rmspe:0.056856
# ...
# [890]	validation_0-rmse:0.054303	validation_1-rmse:0.054708	validation_0-rmspe:0.054275	validation_1-rmspe:0.054572
# [891]	validation_0-rmse:0.0543	validation_1-rmse:0.054706	validation_0-rmspe:0.054271	validation_1-rmspe:0.054569
# [892]	validation_0-rmse:0.054298	validation_1-rmse:0.054704	validation_0-rmspe:0.054269	validation_1-rmspe:0.054567
# [893]	validation_0-rmse:0.054296	validation_1-rmse:0.0547	validation_0-rmspe:0.054267	validation_1-rmspe:0.054563
# [894]	validation_0-rmse:0.054293	validation_1-rmse:0.054697	validation_0-rmspe:0.054264	validation_1-rmspe:0.054559
# [895]	validation_0-rmse:0.054282	validation_1-rmse:0.054685	validation_0-rmspe:0.054255	validation_1-rmspe:0.05455
# [896]	validation_0-rmse:0.05428	validation_1-rmse:0.05468	validation_0-rmspe:0.054254	validation_1-rmspe:0.054546
# [897]	validation_0-rmse:0.054278	validation_1-rmse:0.054677	validation_0-rmspe:0.054254	validation_1-rmspe:0.054544
# [898]	validation_0-rmse:0.054277	validation_1-rmse:0.054675	validation_0-rmspe:0.05425	validation_1-rmspe:0.05454
# [899]	validation_0-rmse:0.054274	validation_1-rmse:0.054672	validation_0-rmspe:0.054247	validation_1-rmspe:0.054537
# [900]	validation_0-rmse:0.054272	validation_1-rmse:0.054668	validation_0-rmspe:0.054244	validation_1-rmspe:0.054532
# [901]	validation_0-rmse:0.054265	validation_1-rmse:0.05466	validation_0-rmspe:0.054237	validation_1-rmspe:0.054523
# [902]	validation_0-rmse:0.054264	validation_1-rmse:0.054659	validation_0-rmspe:0.054235	validation_1-rmspe:0.054522
# [903]	validation_0-rmse:0.054262	validation_1-rmse:0.054658	validation_0-rmspe:0.054234	validation_1-rmspe:0.054521
# [904]	validation_0-rmse:0.054261	validation_1-rmse:0.054658	validation_0-rmspe:0.054232	validation_1-rmspe:0.054521
# [905]	validation_0-rmse:0.054256	validation_1-rmse:0.054654	validation_0-rmspe:0.054226	validation_1-rmspe:0.054515
# [906]	validation_0-rmse:0.054248	validation_1-rmse:0.054647	validation_0-rmspe:0.054217	validation_1-rmspe:0.054507
# [907]	validation_0-rmse:0.054244	validation_1-rmse:0.054644	validation_0-rmspe:0.054215	validation_1-rmspe:0.054506
# [908]	validation_0-rmse:0.054242	validation_1-rmse:0.05464	validation_0-rmspe:0.054216	validation_1-rmspe:0.054505
# [909]	validation_0-rmse:0.05424	validation_1-rmse:0.05464	validation_0-rmspe:0.054213	validation_1-rmspe:0.054505
# [910]	validation_0-rmse:0.054237	validation_1-rmse:0.054634	validation_0-rmspe:0.054211	validation_1-rmspe:0.0545
# [911]	validation_0-rmse:0.054228	validation_1-rmse:0.054633	validation_0-rmspe:0.054202	validation_1-rmspe:0.054498
# [912]	validation_0-rmse:0.054226	validation_1-rmse:0.054634	validation_0-rmspe:0.0542	validation_1-rmspe:0.054499
# [913]	validation_0-rmse:0.054224	validation_1-rmse:0.054634	validation_0-rmspe:0.054198	validation_1-rmspe:0.054499
# [963]	validation_0-rmse:0.054033	validation_1-rmse:0.054484	validation_0-rmspe:0.054007	validation_1-rmspe:0.054347
# [964]	validation_0-rmse:0.054031	validation_1-rmse:0.054487	validation_0-rmspe:0.054006	validation_1-rmspe:0.05435
# [965]	validation_0-rmse:0.054025	validation_1-rmse:0.054481	validation_0-rmspe:0.053999	validation_1-rmspe:0.054343
# [966]	validation_0-rmse:0.054021	validation_1-rmse:0.054477	validation_0-rmspe:0.053993	validation_1-rmspe:0.054336
# [967]	validation_0-rmse:0.054017	validation_1-rmse:0.054475	validation_0-rmspe:0.05399	validation_1-rmspe:0.054336
# [968]	validation_0-rmse:0.054014	validation_1-rmse:0.054473	validation_0-rmspe:0.053985	validation_1-rmspe:0.054333
# [969]	validation_0-rmse:0.054013	validation_1-rmse:0.054472	validation_0-rmspe:0.053984	validation_1-rmspe:0.054331
# [970]	validation_0-rmse:0.05401	validation_1-rmse:0.054469	validation_0-rmspe:0.053984	validation_1-rmspe:0.05433
# [971]	validation_0-rmse:0.054007	validation_1-rmse:0.054467	validation_0-rmspe:0.053981	validation_1-rmspe:0.054328
# [972]	validation_0-rmse:0.054004	validation_1-rmse:0.054465	validation_0-rmspe:0.053978	validation_1-rmspe:0.054327
# [973]	validation_0-rmse:0.053999	validation_1-rmse:0.054464	validation_0-rmspe:0.053971	validation_1-rmspe:0.054324
# [974]	validation_0-rmse:0.053996	validation_1-rmse:0.054462	validation_0-rmspe:0.053967	validation_1-rmspe:0.054321
# [975]	validation_0-rmse:0.053994	validation_1-rmse:0.05446	validation_0-rmspe:0.053966	validation_1-rmspe:0.054319
# [976]	validation_0-rmse:0.053992	validation_1-rmse:0.054458	validation_0-rmspe:0.053966	validation_1-rmspe:0.054319
# [977]	validation_0-rmse:0.05399	validation_1-rmse:0.054457	validation_0-rmspe:0.053966	validation_1-rmspe:0.05432
# [978]	validation_0-rmse:0.053987	validation_1-rmse:0.054451	validation_0-rmspe:0.053961	validation_1-rmspe:0.054312
# [979]	validation_0-rmse:0.053984	validation_1-rmse:0.05445	validation_0-rmspe:0.053957	validation_1-rmspe:0.05431
# [980]	validation_0-rmse:0.05398	validation_1-rmse:0.054442	validation_0-rmspe:0.053954	validation_1-rmspe:0.054304
# [981]	validation_0-rmse:0.053978	validation_1-rmse:0.054439	validation_0-rmspe:0.053954	validation_1-rmspe:0.054302
# [982]	validation_0-rmse:0.053976	validation_1-rmse:0.054438	validation_0-rmspe:0.053953	validation_1-rmspe:0.054303
# [983]	validation_0-rmse:0.053974	validation_1-rmse:0.054436	validation_0-rmspe:0.053949	validation_1-rmspe:0.0543
# [984]	validation_0-rmse:0.053972	validation_1-rmse:0.054436	validation_0-rmspe:0.053947	validation_1-rmspe:0.0543
# [985]	validation_0-rmse:0.053969	validation_1-rmse:0.054434	validation_0-rmspe:0.053946	validation_1-rmspe:0.054299
# [986]	validation_0-rmse:0.053968	validation_1-rmse:0.054434	validation_0-rmspe:0.053943	validation_1-rmspe:0.054298
# [987]	validation_0-rmse:0.053967	validation_1-rmse:0.054431	validation_0-rmspe:0.053942	validation_1-rmspe:0.054296
# [988]	validation_0-rmse:0.053965	validation_1-rmse:0.054429	validation_0-rmspe:0.053937	validation_1-rmspe:0.05429
# [989]	validation_0-rmse:0.053965	validation_1-rmse:0.054429	validation_0-rmspe:0.053938	validation_1-rmspe:0.054291
# [990]	validation_0-rmse:0.053962	validation_1-rmse:0.054426	validation_0-rmspe:0.053937	validation_1-rmspe:0.05429
# [991]	validation_0-rmse:0.05396	validation_1-rmse:0.054426	validation_0-rmspe:0.053935	validation_1-rmspe:0.054289
# [992]	validation_0-rmse:0.053958	validation_1-rmse:0.054426	validation_0-rmspe:0.053933	validation_1-rmspe:0.05429
# [993]	validation_0-rmse:0.053954	validation_1-rmse:0.054426	validation_0-rmspe:0.053927	validation_1-rmspe:0.054287
# [994]	validation_0-rmse:0.053952	validation_1-rmse:0.054422	validation_0-rmspe:0.053924	validation_1-rmspe:0.054282
# [995]	validation_0-rmse:0.05395	validation_1-rmse:0.054423	validation_0-rmspe:0.053921	validation_1-rmspe:0.054282
# [996]	validation_0-rmse:0.053949	validation_1-rmse:0.054421	validation_0-rmspe:0.05392	validation_1-rmspe:0.05428
# [997]	validation_0-rmse:0.053944	validation_1-rmse:0.054416	validation_0-rmspe:0.053915	validation_1-rmspe:0.054274
# [998]	validation_0-rmse:0.053941	validation_1-rmse:0.054416	validation_0-rmspe:0.053913	validation_1-rmspe:0.054276
# [999]	validation_0-rmse:0.05394	validation_1-rmse:0.054418	validation_0-rmspe:0.053913	validation_1-rmspe:0.054279
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=0.8, eta=0.1, gamma=0,
#        importance_type='gain', learning_rate=0.1, max_delta_step=0,
#        max_depth=2, min_child_weight=2, missing=None, n_estimators=1000,
#        n_jobs=-1, nthread=None, objective='reg:linear', random_state=1023,
#        reg_alpha=0.05, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=0, subsample=0.8, tree_method='exact', verbosity=1)

# %%
print("Note that this is not in percentage, thus not to scale of graphs above")
xgb.plot_importance(xgboost_tree)
# Out:
# Note that this is not in percentage, thus not to scale of graphs above

# %%
def rmspe_exp(y, y_hat):
    return rmspe(np.expm1(y), np.expm1(y_hat))

rmpse_xg_scorer = make_scorer(rmspe_exp, greater_is_better = False) # Loss function

def score(model, X_train, y_train, y_test, y_hat):
    score = cross_val_score(model, X_train, y_train, scoring=rmpse_xg_scorer, cv=5)
    print('Mean', score.mean())
    print('Variance', score.var())
    print('RMSPE', rmspe(y_test, np.expm1(y_hat)))

y_hat = xgboost_tree.predict(X_test[X])
score(xgboost_tree, X_train[X], np.log1p(y_train), y_test, y_hat)
# Out:
# [21:33:01] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:33:33] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:34:04] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:34:34] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:35:05] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Mean -0.05545218890918977
# Variance 2.1567442008742737e-07
# RMSPE 0.054274273124918476

# %%
test = pd.read_csv("./assets/test_v2.csv", parse_dates=[2], dtype=types)
features = build_features(test, store)

y_hat = np.expm1(xgboost_tree.predict(features[X]))

df = pd.DataFrame({"Id": range(1, len(test) + 1), 'Sales': y_hat})
df.loc[test['Open'] == 0, 'Sales'] = 1
df.to_csv('sales.csv', index=False)
